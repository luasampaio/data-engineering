# %% [markdown]
# ## Observações
#
# - how='all' significa que uma linha será removida somente se todos os seus valores forem nulos.
# - how='any' significa que uma linha será removida se pelo menos um dos seus valores for nulo.

# %%
from pyspark.sql.functions import col
import json
import glob
import re
import pandas as pd

# %%
from pyspark.sql import SparkSession

# Criando uma SparkSession
spark = SparkSession.builder.appName("app").getOrCreate()

# Link corrigido para o arquivo CSV (usando raw.githubusercontent.com)
csv_url = "https://raw.githubusercontent.com/luasampaio/data-engineering-projects/main/_datasets/nyc_uber_2014.csv"

# Baixando o arquivo CSV para um DataFrame Pandas
import pandas as pd
import requests
from io import StringIO

response = requests.get(csv_url)
csv_data = StringIO(response.text)  # Converte o texto recebido para um objeto legível

# %%
# Baixando o arquivo CSV para um DataFrame Pandas
import pandas as pd
import requests
from io import StringIO

response = requests.get(csv_url)
csv_data = StringIO(response.text)  # Converte o texto recebido para um objeto legível

# %%
# print(csv_data.getvalue())
# Out:
# ,Date/Time,Lat,Lon,Base
# 0,4/1/2014 0:11:00,40.769,-73.9549,B02512
# 1,4/1/2014 0:17:00,40.7267,-74.0345,B02512
# 2,4/1/2014 0:21:00,40.7316,-73.9873,B02512
# 3,4/1/2014 0:28:00,40.7588,-73.9776,B02512
# 4,4/1/2014 0:33:00,40.7594,-73.9722,B02512
# 5,4/1/2014 0:33:00,40.7383,-74.0403,B02512
# 6,4/1/2014 0:39:00,40.7223,-73.9887,B02512
# 7,4/1/2014 0:45:00,40.762,-73.979,B02512
# 8,4/1/2014 0:55:00,40.7524,-73.99600000000001,B02512
# 9,4/1/2014 1:01:00,40.7575,-73.9846,B02512
# 10,4/1/2014 1:19:00,40.7256,-73.9869,B02512
# 11,4/1/2014 1:48:00,40.7591,-73.9684,B02512
# 12,4/1/2014 1:49:00,40.7271,-73.9803,B02512
# 13,4/1/2014 2:11:00,40.6463,-73.7896,B02512
# 14,4/1/2014 2:25:00,40.7564,-73.9167,B02512
# 15,4/1/2014 2:31:00,40.7666,-73.9531,B02512
# 16,4/1/2014 2:43:00,40.758,-73.9761,B02512
# 17,4/1/2014 3:22:00,40.7238,-73.9821,B02512
# 18,4/1/2014 3:35:00,40.7531,-74.0039,B02512
# 19,4/1/2014 3:35:00,40.7389,-74.0393,B02512
# 20,4/1/2014 3:41:00,40.7619,-73.9715,B02512
# ...

# %%
df = pd.read_csv(csv_data)

# %%
display(df)
# Out:
#      Unnamed: 0         Date/Time      Lat      Lon    Base
# 0             0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1             1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2             2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3             3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4             4  4/1/2014 0:33:00  40.7594 -73.9722  B02512
# ..          ...               ...      ...      ...     ...
# 292          94  6/1/2014 6:27:00  40.7554 -73.9738  B02512
# 293          95  6/1/2014 6:35:00  40.7543 -73.9817  B02512
# 294          96  6/1/2014 6:37:00  40.7751 -73.9633  B02512
# 295          97  6/1/2014 6:46:00  40.6952 -74.1784  B02512
# 296          98  6/1/2014 6:51:00  40.7621 -73.9817  B02512
#
# [297 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  297 non-null    int64
#  1   Date/Time   297 non-null    object
#  2   Lat         297 non-null    float64
#  3   Lon         297 non-null    float64
#  4   Base        297 non-null    object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 11.7+ KB

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date/Time', 'Lat', 'Lon', 'Base'], dtype='object')

# %% [markdown]
# Adicionando a colunas em Maiusculo

# %%
df.columns = [col.lower() for col in df.columns]

# %% [markdown]
# Alternativa para ver o nome da coluna

# %%
for Loop in df.columns:
    print(Loop)
# Out:
# unnamed: 0
# date/time
# lat
# lon
# base

# %% [markdown]
# - how='all' significa que uma linha será removida somente se todos os seus valores forem nulos.
# - how='any' significa que uma linha será removida se pelo menos um dos seus valores for nulo.

# %%
display(df.dropna(how='all'))
# Out:
#      unnamed: 0         date/time      lat      lon    base
# 0             0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1             1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2             2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3             3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4             4  4/1/2014 0:33:00  40.7594 -73.9722  B02512
# ..          ...               ...      ...      ...     ...
# 292          94  6/1/2014 6:27:00  40.7554 -73.9738  B02512
# 293          95  6/1/2014 6:35:00  40.7543 -73.9817  B02512
# 294          96  6/1/2014 6:37:00  40.7751 -73.9633  B02512
# 295          97  6/1/2014 6:46:00  40.6952 -74.1784  B02512
# 296          98  6/1/2014 6:51:00  40.7621 -73.9817  B02512
#
# [297 rows x 5 columns]
