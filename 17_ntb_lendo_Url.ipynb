# %% [markdown]
# <a href="https://colab.research.google.com/github/luasampaio/data-engineering/blob/main/18_ntb_lendo_Url.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# URL para o conteúdo bruto do arquivo CSV
url = 'https://raw.githubusercontent.com/luasampaio/datasets/main/employee.csv'

# Lê o arquivo CSV diretamente do URL
df = pd.read_csv(url)

# Exibe as primeiras linhas do DataFrame
print(df.head())
# Out:
#    emp_id emp_name  dept_id  salary
# 0       1    Alice      100   60000
# 1       2      Bob      101   55000
# 2       3  Charlie      100   70000
# 3       4    David      102   48000
# 4       5      Eve      101   65000

# %%
df.columns
# Out:
# Index(['emp_id', 'emp_name', 'dept_id', 'salary'], dtype='object')

# %%
df = df.add_prefix('employee_')

# %% [markdown]
# Adiciona Prefixo

# %%
df
# Out:
#    employee_emp_id employee_emp_name  employee_dept_id  employee_salary
# 0                1             Alice               100            60000
# 1                2               Bob               101            55000
# 2                3           Charlie               100            70000
# 3                4             David               102            48000
# 4                5               Eve               101            65000
